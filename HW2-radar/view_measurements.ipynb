# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/tyri_meas_data_202311.csv')
df.set_index('datetime', inplace=True)
df
# Out:
#                      Türi_TAX1H  Türi_PR1H
# datetime
# 2023-11-01 00:00:00        11.9        1.2
# 2023-11-01 01:00:00        11.7        0.4
# 2023-11-01 02:00:00        11.4        0.3
# 2023-11-01 03:00:00        10.8        0.0
# 2023-11-01 04:00:00        10.1        0.0
# ...                         ...        ...
# 2023-11-30 19:00:00        -3.5        0.0
# 2023-11-30 20:00:00        -3.6        0.1
# 2023-11-30 21:00:00        -3.6        0.0
# 2023-11-30 22:00:00        -3.7        0.0
# 2023-11-30 23:00:00        -3.8        0.0
#
# [720 rows x 2 columns]

# %%
df['Türi_PR1H'].plot()
plt.xticks(rotation=45)
#plt.plot(df['datetime'], df['Türi_PR1H'])
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2023-11-26 20:00:00'),
#   Text(0.0, 0, '2023-11-01 00:00:00'),
#   Text(100.0, 0, '2023-11-05 04:00:00'),
#   Text(200.0, 0, '2023-11-09 08:00:00'),
#   Text(300.0, 0, '2023-11-13 12:00:00'),
#   Text(400.0, 0, '2023-11-17 16:00:00'),
#   Text(500.0, 0, '2023-11-21 20:00:00'),
#   Text(600.0, 0, '2023-11-26 00:00:00'),
#   Text(700.0, 0, '2023-11-30 04:00:00'),
#   Text(800.0, 0, '')])
